# %%
from os import listdir
from os.path import isfile, join
import re
import pandas as pd

from lexnlp.extract.en.entities import nltk_re
from lexnlp.nlp.en.segments import sentences
from lexnlp.utils import parse_df

# %%
DATA_PATH = "..\data\interim\sfcr"

# %%
files = [f for f in listdir(DATA_PATH) if isfile(join(DATA_PATH, f)) and f[-3:]=='txt']
documents = []
for file_name in files:
    file = open(join(DATA_PATH, file_name), "rb")
    text = file.read().decode('utf-8')
    file.close()
    #text = text.replace("\n", " ")
    documents.append(text)

# %%
print(len(documents))
# Out:
# 13

# %% [markdown]
# # Get companies

# %%
# nltk_re performs a complex regular expression for finding company entities

l = list(nltk_re.get_companies(documents[0]))

# %%
l[0:5]
# Out:
# [Achmea B.V., (19993, 20008), Achmea Reinsurance
#  Company N.V., (20988, 21021), Achmea B.V., (21548, 21563), Achmea B.V., (22175, 22187), Levensverzekeringen N.V., (22207, 22232)]

# %% [markdown]
# # Accounting firms

# %% [markdown]
# Dutch accounting firms are supervised by the AFM. It publishes a register with accounting firms: https://www.afm.nl/en/professionals/registers/vergunningenregisters/accountantsorganisaties

# %%
# file directly downloaded from AFM website
f = "..//dictionary//nl//AFM//accountantsorganisaties.csv"
df = pd.read_csv(f, encoding = 'latin-1', sep= ';').set_index('Naam organisatie')
# additional file for aliases of firm names (for example EY instead of Ernst & Young Accountants)
f = "..//dictionary//nl//AFM//accountantsorganisaties-alias.csv"
alias = pd.read_csv(f, sep = ',', encoding = 'latin-1').set_index('Naam organisatie')
df = df.join(alias).reset_index()

parse_columns = ('Naam organisatie', 'Korte naam', 'Afkorting')
result_columns = {'Naam organisatie': 'name'}
preformed_entity = {'entity_type': 'accounting firm', 
                    'source'     : 'AFM', 
                    'country'    : 'NL'}

# %%
df_results = pd.DataFrame()
for idx, document in enumerate(documents):
    items = list(parse_df.DataframeEntityParser(df, parse_columns, result_columns, preformed_entity).get_entities_from_text(document))
    for i in items:
        df_results = df_results.append(pd.DataFrame(columns = ['file name']+list(i.keys()), data = [[files[idx]] + list(i.values())]))
df_results
# Out:
#                                            file name  location_start  \
# 0                          2018_Achmea B.V._SFCR.txt           25077
# 0                          2018_Achmea B.V._SFCR.txt           39296
# 0              2018_Aegon Levensverzekering_SFCR.txt           27752
# 0              2018_Aegon Levensverzekering_SFCR.txt           27752
# 0              2018_Aegon Schadeverzekering_SFCR.txt           16715
# 0              2018_Aegon Schadeverzekering_SFCR.txt           16715
# 0                       2018_Aegon Spaarkas_SFCR.txt           22764
# 0                       2018_Aegon Spaarkas_SFCR.txt           22807
# 0                       2018_Aegon Spaarkas_SFCR.txt           22764
# 0                       2018_Aegon Spaarkas_SFCR.txt           22807
# 0  2018_ASR Aanvullende Ziektekostenverzekeringen...           33935
# 0  2018_ASR Aanvullende Ziektekostenverzekeringen...           34373
# 0  2018_ASR Basis Ziektekostenverzekeringen N.V._...           35020
# 0  2018_ASR Basis Ziektekostenverzekeringen N.V._...           35454
# 0           2018_ASR Levensverzekering N.V._SFCR.txt           31117
# 0           2018_ASR Levensverzekering N.V._SFCR.txt           31547
# 0           2018_ASR Levensverzekering N.V._SFCR.txt           44163
# 0                   2018_ASR Nederland N.V._SFCR.txt           19905
# 0                   2018_ASR Nederland N.V._SFCR.txt           81919
# 0           2018_ASR Schadeverzekering N.V._SFCR.txt           31129
# 0           2018_ASR Schadeverzekering N.V._SFCR.txt           31553
# 0           2018_ASR Schadeverzekering N.V._SFCR.txt           43090
# 0              2018_Nationale-Nederlanden_SFCR_1.txt           10220
# 0              2018_Nationale-Nederlanden_SFCR_1.txt           10220
# 0                     2018_Optas Pensioenen_SFCR.txt           21116
# 0                     2018_Optas Pensioenen_SFCR.txt           21072
# 0                     2018_Optas Pensioenen_SFCR.txt           21116
# 0                            2018_VIVAT N.V_SFCR.txt           22285
# 0                            2018_VIVAT N.V_SFCR.txt           22442
# 0                            2018_VIVAT N.V_SFCR.txt           22285
# 0                            2018_VIVAT N.V_SFCR.txt           22442
# 0                            2018_VIVAT N.V_SFCR.txt           54851
# 0                            2018_VIVAT N.V_SFCR.txt           55112
# 0                            2018_VIVAT N.V_SFCR.txt           22473
# 0                            2018_VIVAT N.V_SFCR.txt           22478
# 0                            2018_VIVAT N.V_SFCR.txt           22826
#
#    location_end source                                     name  \
# 0         25101    AFM  PricewaterhouseCoopers Accountants N.V.
# 0         39320    AFM  PricewaterhouseCoopers Accountants N.V.
# 0         27793    AFM  PricewaterhouseCoopers Accountants N.V.
# 0         27776    AFM  PricewaterhouseCoopers Accountants N.V.
# 0         16756    AFM  PricewaterhouseCoopers Accountants N.V.
# 0         16739    AFM  PricewaterhouseCoopers Accountants N.V.
# 0         22805    AFM  PricewaterhouseCoopers Accountants N.V.
# 0         22848    AFM  PricewaterhouseCoopers Accountants N.V.
# 0         22788    AFM  PricewaterhouseCoopers Accountants N.V.
# 0         22831    AFM  PricewaterhouseCoopers Accountants N.V.
# 0         33939    AFM            Ernst & Young Accountants LLP
# 0         34377    AFM            Ernst & Young Accountants LLP
# 0         35024    AFM            Ernst & Young Accountants LLP
# 0         35458    AFM            Ernst & Young Accountants LLP
# 0         31121    AFM            Ernst & Young Accountants LLP
# 0         31551    AFM            Ernst & Young Accountants LLP
# 0         44167    AFM            Ernst & Young Accountants LLP
# 0         19909    AFM            Ernst & Young Accountants LLP
# 0         81923    AFM            Ernst & Young Accountants LLP
# 0         31133    AFM            Ernst & Young Accountants LLP
# 0         31557    AFM            Ernst & Young Accountants LLP
# 0         43094    AFM            Ernst & Young Accountants LLP
# 0         10243    AFM                    KPMG Accountants N.V.
# 0         10226    AFM                    KPMG Accountants N.V.
# 0         21157    AFM  PricewaterhouseCoopers Accountants N.V.
# 0         21096    AFM  PricewaterhouseCoopers Accountants N.V.
# 0         21140    AFM  PricewaterhouseCoopers Accountants N.V.
# 0         22316    AFM            Ernst & Young Accountants LLP
# 0         22473    AFM            Ernst & Young Accountants LLP
# 0         22300    AFM            Ernst & Young Accountants LLP
# 0         22457    AFM            Ernst & Young Accountants LLP
# 0         54875    AFM  PricewaterhouseCoopers Accountants N.V.
# 0         55136    AFM  PricewaterhouseCoopers Accountants N.V.
# 0         22477    AFM            Ernst & Young Accountants LLP
# 0         22482    AFM            Ernst & Young Accountants LLP
# 0         22830    AFM            Ernst & Young Accountants LLP
#
#        entity_type country
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL
# 0  accounting firm      NL

# %% [markdown]
# # Insurance undertakings

# %% [markdown]
# EIOPA's register includes all European insurance undertakings.

# %%
f = "..//dictionary//common//EIOPA//DATINS_Export_637110803393817886.csv"
df = pd.read_csv(f, encoding = 'latin-1', sep= ';')

# %%
parse_columns = ('International Name', 'Official name of the entity')
result_columns = {'International Name': 'name', 'Home Country': 'country'}
preformed_entity = {'entity_type': 'insurance undertaking', 
                    'source': 'EIOPA'}

# %%
df_results = pd.DataFrame()
for idx, document in enumerate(documents[0:1]):
    items = list(parse_df.DataframeEntityParser(df, parse_columns, result_columns, preformed_entity).get_entities_from_text(document))
    for i in items:
        df_results = df_results.append(pd.DataFrame(columns = ['file name']+list(i.keys()), data = [[files[idx]] + list(i.values())]))
df_results
# Out:
#                     file name  location_start  location_end source  \
# 0   2018_Achmea B.V._SFCR.txt           22232         22265  EIOPA
# 0   2018_Achmea B.V._SFCR.txt           22265         22281  EIOPA
# 0   2018_Achmea B.V._SFCR.txt           22284         22317  EIOPA
# 0   2018_Achmea B.V._SFCR.txt           33762         33795  EIOPA
# 0   2018_Achmea B.V._SFCR.txt           35599         35632  EIOPA
# 0   2018_Achmea B.V._SFCR.txt           35917         35963  EIOPA
# 0   2018_Achmea B.V._SFCR.txt           35964         35997  EIOPA
# 0   2018_Achmea B.V._SFCR.txt           35998         36014  EIOPA
# 0   2018_Achmea B.V._SFCR.txt           36015         36048  EIOPA
# 0   2018_Achmea B.V._SFCR.txt           36092         36123  EIOPA
# 0   2018_Achmea B.V._SFCR.txt           36123         36162  EIOPA
# 0   2018_Achmea B.V._SFCR.txt           36162         36191  EIOPA
# 0   2018_Achmea B.V._SFCR.txt           36197         36228  EIOPA
# 0   2018_Achmea B.V._SFCR.txt           36228         36263  EIOPA
# 0   2018_Achmea B.V._SFCR.txt           36263         36298  EIOPA
# 0   2018_Achmea B.V._SFCR.txt           54752         54785  EIOPA
# 0   2018_Achmea B.V._SFCR.txt           54785         54801  EIOPA
# 0   2018_Achmea B.V._SFCR.txt           54882         54913  EIOPA
# 0   2018_Achmea B.V._SFCR.txt           54913         54952  EIOPA
# 0   2018_Achmea B.V._SFCR.txt           54952         54987  EIOPA
# 0   2018_Achmea B.V._SFCR.txt           54993         55024  EIOPA
# 0   2018_Achmea B.V._SFCR.txt           55024         55053  EIOPA
# 0   2018_Achmea B.V._SFCR.txt           55053         55088  EIOPA
# 0   2018_Achmea B.V._SFCR.txt           55162         55208  EIOPA
# 0   2018_Achmea B.V._SFCR.txt           55652         55685  EIOPA
# 0   2018_Achmea B.V._SFCR.txt           59255         59288  EIOPA
# 0   2018_Achmea B.V._SFCR.txt           69252         69291  EIOPA
# 0   2018_Achmea B.V._SFCR.txt           69291         69326  EIOPA
# 0   2018_Achmea B.V._SFCR.txt           69326         69355  EIOPA
# 0   2018_Achmea B.V._SFCR.txt           69461         69492  EIOPA
# ..                        ...             ...           ...    ...
# 0   2018_Achmea B.V._SFCR.txt          377519        377552  EIOPA
# 0   2018_Achmea B.V._SFCR.txt          377552        377568  EIOPA
# 0   2018_Achmea B.V._SFCR.txt          377571        377604  EIOPA
# 0   2018_Achmea B.V._SFCR.txt          379041        379087  EIOPA
# 0   2018_Achmea B.V._SFCR.txt          379087        379120  EIOPA
# 0   2018_Achmea B.V._SFCR.txt          379120        379136  EIOPA
# 0   2018_Achmea B.V._SFCR.txt          379136        379169  EIOPA
# 0   2018_Achmea B.V._SFCR.txt          379227        379254  EIOPA
# 0   2018_Achmea B.V._SFCR.txt          382599        382632  EIOPA
# 0   2018_Achmea B.V._SFCR.txt          382766        382799  EIOPA
# 0   2018_Achmea B.V._SFCR.txt          382934        382980  EIOPA
# 0   2018_Achmea B.V._SFCR.txt          382980        383013  EIOPA
# 0   2018_Achmea B.V._SFCR.txt          383013        383029  EIOPA
# 0   2018_Achmea B.V._SFCR.txt          383029        383062  EIOPA
# 0   2018_Achmea B.V._SFCR.txt          383063        383094  EIOPA
# 0   2018_Achmea B.V._SFCR.txt          387646        387692  EIOPA
# 0   2018_Achmea B.V._SFCR.txt          389549        389582  EIOPA
# 0   2018_Achmea B.V._SFCR.txt          390911        390927  EIOPA
# 0   2018_Achmea B.V._SFCR.txt          391913        391946  EIOPA
# 0   2018_Achmea B.V._SFCR.txt          392134        392165  EIOPA
# 0   2018_Achmea B.V._SFCR.txt          392382        392413  EIOPA
# 0   2018_Achmea B.V._SFCR.txt          392525        392556  EIOPA
# 0   2018_Achmea B.V._SFCR.txt          392651        392686  EIOPA
# 0   2018_Achmea B.V._SFCR.txt          393244        393279  EIOPA
# 0   2018_Achmea B.V._SFCR.txt          393323        393352  EIOPA
# 0   2018_Achmea B.V._SFCR.txt          395151        395184  EIOPA
# 0   2018_Achmea B.V._SFCR.txt          395203        395236  EIOPA
# 0   2018_Achmea B.V._SFCR.txt          396107        396153  EIOPA
# 0   2018_Achmea B.V._SFCR.txt          396255        396288  EIOPA
# 0   2018_Achmea B.V._SFCR.txt          396323        396356  EIOPA
#
#                                             name country  \
# 0                Achmea Schadeverzekeringen N.V.      NL
# 0                                 N.V. Hagelunie      NL
# 0                Achmea Reinsurance Company N.V.      NL
# 0                Achmea Schadeverzekeringen N.V.      NL
# 0                Achmea Reinsurance Company N.V.      NL
# 0   Achmea Pensioen- en Levensverzekeringen N.V.      NL
# 0                Achmea Schadeverzekeringen N.V.      NL
# 0                                 N.V. Hagelunie      NL
# 0                Achmea Reinsurance Company N.V.      NL
# 0                  Achmea Zorgverzekeringen N.V.      NL
# 0          Zilveren Kruis Zorgverzekeringen N.V.      NL
# 0                    FBTO Zorgverzekeringen N.V.      NL
# 0                  Achmea Zorgverzekeringen N.V.      NL
# 0              Interpolis Zorgverzekeringen N.V.      NL
# 0              De Friesland Zorgverzekeraar N.V.      NL
# 0                Achmea Schadeverzekeringen N.V.      NL
# 0                                 N.V. Hagelunie      NL
# 0                  Achmea Zorgverzekeringen N.V.      NL
# 0          Zilveren Kruis Zorgverzekeringen N.V.      NL
# 0              Interpolis Zorgverzekeringen N.V.      NL
# 0                  Achmea Zorgverzekeringen N.V.      NL
# 0                    FBTO Zorgverzekeringen N.V.      NL
# 0              De Friesland Zorgverzekeraar N.V.      NL
# 0   Achmea Pensioen- en Levensverzekeringen N.V.      NL
# 0                Achmea Reinsurance Company N.V.      NL
# 0                Achmea Reinsurance Company N.V.      NL
# 0          Zilveren Kruis Zorgverzekeringen N.V.      NL
# 0              De Friesland Zorgverzekeraar N.V.      NL
# 0                    FBTO Zorgverzekeringen N.V.      NL
# 0                  Achmea Zorgverzekeringen N.V.      NL
# ..                                           ...     ...
# 0                Achmea Schadeverzekeringen N.V.      NL
# 0                                 N.V. Hagelunie      NL
# 0                Achmea Reinsurance Company N.V.      NL
# 0   Achmea Pensioen- en Levensverzekeringen N.V.      NL
# 0                Achmea Schadeverzekeringen N.V.      NL
# 0                                 N.V. Hagelunie      NL
# 0                Achmea Reinsurance Company N.V.      NL
# 0                      Managed Pension Funds Ltd      UK
# 0                Achmea Reinsurance Company N.V.      NL
# 0                Achmea Reinsurance Company N.V.      NL
# 0   Achmea Pensioen- en Levensverzekeringen N.V.      NL
# 0                Achmea Schadeverzekeringen N.V.      NL
# 0                                 N.V. Hagelunie      NL
# 0                Achmea Reinsurance Company N.V.      NL
# 0                  Achmea Zorgverzekeringen N.V.      NL
# 0   Achmea Pensioen- en Levensverzekeringen N.V.      NL
# 0                Achmea Schadeverzekeringen N.V.      NL
# 0                                 N.V. Hagelunie      NL
# 0                Achmea Reinsurance Company N.V.      NL
# 0                  Achmea Zorgverzekeringen N.V.      NL
# 0                  Achmea Zorgverzekeringen N.V.      NL
# 0                  Achmea Zorgverzekeringen N.V.      NL
# 0              Interpolis Zorgverzekeringen N.V.      NL
# 0              De Friesland Zorgverzekeraar N.V.      NL
# 0                    FBTO Zorgverzekeringen N.V.      NL
# 0                Achmea Schadeverzekeringen N.V.      NL
# 0                Achmea Reinsurance Company N.V.      NL
# 0   Achmea Pensioen- en Levensverzekeringen N.V.      NL
# 0                Achmea Schadeverzekeringen N.V.      NL
# 0                Achmea Reinsurance Company N.V.      NL
#
#               entity_type
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# ..                    ...
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
# 0   insurance undertaking
#
# [630 rows x 7 columns]
